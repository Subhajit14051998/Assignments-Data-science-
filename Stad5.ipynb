# %% [markdown]
# 1.  Here’s the Python code to calculate the 95% confidence interval for
#     the given data:
#
# import scipy.stats as stats
#
# mean = 50 std_dev = 5 sample_size = \# specify your sample size
#
# confidence_level = 0.95 margin_of_error = stats.norm.ppf((1 +
# confidence_level) / 2) \* (std_dev / (sample_size \*\* 0.5))
#
# lower_bound = mean - margin_of_error upper_bound = mean +
# margin_of_error
#
# print(“95% Confidence Interval:”, (lower_bound, upper_bound))
# Interpretation: We are 95% confident that the true population mean lies
# between the calculated lower and upper bounds.
#
# 1.  To perform a chi-square goodness of fit test in Python:
#
# import scipy.stats as stats
#
# observed = \[observed_blue_count, observed_orange_count,
# observed_green_count, observed_yellow_count, observed_red_count,
# observed_brown_count\] expected = \[expected_blue_count,
# expected_orange_count, expected_green_count, expected_yellow_count,
# expected_red_count, expected_brown_count\]
#
# chi2_stat, p_value = stats.chisquare(observed, expected)
#
# alpha = 0.05 if p_value \< alpha: print(“Reject null hypothesis:
# Distribution does not match expected.”) else: print(“Fail to reject null
# hypothesis: Distribution matches expected.”) 4. Calculate the 95%
# confidence interval for the true proportion of smokers:
#
# import statsmodels.stats.proportion as proportion
#
# total_population = 500 smokers = 60 confidence_level = 0.95
#
# confidence_interval = proportion.proportion_confint(smokers,
# total_population, alpha=(1-confidence_level))
#
# print(“95% Confidence Interval:”, confidence_interval) 5. Calculate the
# 90% confidence interval for the given data:
#
# mean = 75 std_dev = 12 sample_size = \# specify your sample size
#
# confidence_level = 0.90 margin_of_error = stats.norm.ppf((1 +
# confidence_level) / 2) \* (std_dev / (sample_size \*\* 0.5))
#
# lower_bound = mean - margin_of_error upper_bound = mean +
# margin_of_error
#
# print(“90% Confidence Interval:”, (lower_bound, upper_bound))
# Interpretation: We are 90% confident that the true population mean lies
# between the calculated lower and upper bounds.
#
# 1.  To plot the chi-square distribution with shading: import numpy as np
#     import matplotlib.pyplot as plt
#
# degrees_of_freedom = 10 chi2_values = np.linspace(0, 30, 500)
# chi2_distribution = stats.chi2.pdf(chi2_values, df=degrees_of_freedom)
#
# plt.plot(chi2_values, chi2_distribution, label=‘Chi-Square
# Distribution’) plt.fill_between(chi2_values\[chi2_values \>= 15\],
# chi2_distribution\[chi2_values \>= 15\], color=‘grey’, alpha=0.5)
# plt.xlabel(‘Chi-Square Value’) plt.ylabel(‘Probability Density’)
# plt.title(‘Chi-Square Distribution with Shaded Area’) plt.legend()
# plt.show() 7. Calculate the 99% confidence interval for the true
# proportion of people who prefer Coke: total_sample = 1000 coke_preferred
# = 520 confidence_level = 0.99
#
# confidence_interval = proportion.proportion_confint(coke_preferred,
# total_sample, alpha=(1-confidence_level))
#
# print(“99% Confidence Interval:”, confidence_interval) 8. Perform the
# chi-square goodness of fit test for the coin toss:
#
# observed = \[45, 55\] \# Observed frequencies of tails and heads
# expected = \[50, 50\] \# Expected frequencies for a fair coin
#
# chi2_stat, p_value = stats.chisquare(observed, expected)
#
# alpha = 0.05 if p_value \< alpha: print(“Reject null hypothesis:
# Observed frequencies do not match expected.”) else: print(“Fail to
# reject null hypothesis: Observed frequencies match expected.”)
#
# 11.To conduct a hypothesis test in this scenario, we can use a t-test
# since the population standard deviation is unknown. Here’s how we can
# perform the hypothesis test using Python:
#
# import scipy.stats as stats
#
# sample_mean = 72 sample_std_dev = 10 sample_size = 30 population_mean =
# 70 significance_level = 0.05
#
# # Calculate the t-statistic
#
# t_statistic = (sample_mean - population_mean) / (sample_std_dev /
# (sample_size \*\* 0.5))
#
# # Calculate the degrees of freedom
#
# degrees_of_freedom = sample_size - 1
#
# # Calculate the critical t-value for a two-tailed test
#
# critical_t\_value = stats.t.ppf(1 - significance_level / 2,
# df=degrees_of_freedom)
#
# # Calculate the p-value
#
# p_value = 2 \* (1 - stats.t.cdf(abs(t_statistic),
# df=degrees_of_freedom))
#
# # Compare t-statistic with critical t-value and p-value with significance level
#
# if abs(t_statistic) \> critical_t\_value or p_value \<
# significance_level: print(“Reject null hypothesis: Population mean is
# significantly different from 70.”) else: print(“Fail to reject null
# hypothesis: No significant difference from 70.”) This code calculates
# the t-statistic, compares it with the critical t-value, and also
# compares the p-value with the significance level to make a decision
# regarding the null hypothesis. If the t-statistic is greater than the
# critical t-value or the p-value is less than the significance level, you
# would reject the null hypothesis and conclude that the population mean
# is significantly different from 70. Otherwise, you would fail to reject
# the null hypothesis.
